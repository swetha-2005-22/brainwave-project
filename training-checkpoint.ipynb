# %%
import numpy as np
import pandas as pd

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-f5c852ec-388f-4e1c-9b96-0ca1869f3cd9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f5c852ec-388f-4e1c-9b96-0ca1869f3cd9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
brainwave = pd.read_csv('eeg_signals.csv')

# %%
brainwave
# Out:
#          alpha       beta     gamma      theta  emotion
# 0    11.993428  17.852355  6.399355   9.556722      Sad
# 1    10.723471  19.818833  5.924634   6.897629  Relaxed
# 2    12.295377  13.202865  5.059630   6.363602      Sad
# 3    14.046060  17.125938  4.353063   7.993251  Relaxed
# 4    10.531693  14.698715  5.698223   7.659631  Relaxed
# ..         ...        ...       ...        ...      ...
# 495  12.077820  15.437799  7.006093  10.140300      Sad
# 496   8.925508  19.595373  7.061504   7.946957      Sad
# 497  10.619323  17.281686  6.208366   6.236251    Happy
# 498   9.248763  14.857642  6.024063   7.673866  Relaxed
# 499   8.234401  17.145166  5.592527   6.510195      Sad
#
# [500 rows x 5 columns]

# %%
brainwave.shape
# Out:
# (500, 5)

# %%
brainwave.columns
# Out:
# Index(['alpha', 'beta', 'gamma', 'theta', 'emotion'], dtype='object')

# %%
brainwave.info
# Out:
# <bound method DataFrame.info of          alpha       beta     gamma      theta  emotion
# 0    11.993428  17.852355  6.399355   9.556722      Sad
# 1    10.723471  19.818833  5.924634   6.897629  Relaxed
# 2    12.295377  13.202865  5.059630   6.363602      Sad
# 3    14.046060  17.125938  4.353063   7.993251  Relaxed
# 4    10.531693  14.698715  5.698223   7.659631  Relaxed
# ..         ...        ...       ...        ...      ...
# 495  12.077820  15.437799  7.006093  10.140300      Sad
# 496   8.925508  19.595373  7.061504   7.946957      Sad
# 497  10.619323  17.281686  6.208366   6.236251    Happy
# 498   9.248763  14.857642  6.024063   7.673866  Relaxed
# 499   8.234401  17.145166  5.592527   6.510195      Sad
#
# [500 rows x 5 columns]>

# %%
brainwave.isnull().sum()
# Out:
# alpha      0
# beta       0
# gamma      0
# theta      0
# emotion    0
# dtype: int64

# %%
x=brainwave[['alpha', 'beta', 'gamma', 'theta']]

# %%
x
# Out:
#          alpha       beta     gamma      theta
# 0    11.993428  17.852355  6.399355   9.556722
# 1    10.723471  19.818833  5.924634   6.897629
# 2    12.295377  13.202865  5.059630   6.363602
# 3    14.046060  17.125938  4.353063   7.993251
# 4    10.531693  14.698715  5.698223   7.659631
# ..         ...        ...       ...        ...
# 495  12.077820  15.437799  7.006093  10.140300
# 496   8.925508  19.595373  7.061504   7.946957
# 497  10.619323  17.281686  6.208366   6.236251
# 498   9.248763  14.857642  6.024063   7.673866
# 499   8.234401  17.145166  5.592527   6.510195
#
# [500 rows x 4 columns]

# %%
y=brainwave[['emotion']]

# %%
y
# Out:
#      emotion
# 0        Sad
# 1    Relaxed
# 2        Sad
# 3    Relaxed
# 4    Relaxed
# ..       ...
# 495      Sad
# 496      Sad
# 497    Happy
# 498  Relaxed
# 499      Sad
#
# [500 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y, test_size=0.1)

# %%
x_train.shape
# Out:
# (450, 4)

# %%
x_test.shape
# Out:
# (50, 4)

# %%
y_train.shape
# Out:
# (450, 1)

# %%
y_test.shape
# Out:
# (50, 1)

# %%
import os

# Create the 'model' folder if it does not exist
os.makedirs("model", exist_ok=True)

# Save model + scaler + label encoder
joblib.dump(rf, "model/brainwave_model.pkl")
joblib.dump(scaler, "model/scaler.pkl")
joblib.dump(le, "model/label_encoder.pkl")
# Out:
# ['model/label_encoder.pkl']

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import joblib

# Load dataset (make sure path is correct!)
df = pd.read_csv("eeg_signals.csv")

# Features & Target
X = df.drop("emotion", axis=1)   # EEG features: alpha, beta, gamma, theta
y = df["emotion"]                # Target column: Happy, Sad, Relaxed

# Encode labels into numeric form
le = LabelEncoder()
y_encoded = le.fit_transform(y)  # Happy=0, Relaxed=1, Sad=2 (order may vary)

# Scale features (important for EEG data)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Train-test split
x_train, x_test, y_train, y_test = train_test_split(
    X_scaled, y_encoded, test_size=0.2, random_state=42, stratify=y_encoded
)

# Train Random Forest Classifier
rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(x_train, y_train)

# Predict
y_pred = rf.predict(x_test)

# Evaluate
acc = accuracy_score(y_test, y_pred)
print("Accuracy:", acc)
print("\nClassification Report:\n", classification_report(y_test, y_pred, target_names=le.classes_))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))

# Save model + scaler + label encoder
joblib.dump(rf, "model/brainwave_model.pkl")
joblib.dump(scaler, "model/scaler.pkl")
joblib.dump(le, "model/label_encoder.pkl")
# Out:
# Accuracy: 0.3
#
# Classification Report:
#                precision    recall  f1-score   support
#
#        Happy       0.39      0.33      0.36        36
#      Relaxed       0.33      0.42      0.37        31
#          Sad       0.17      0.15      0.16        33
#
#     accuracy                           0.30       100
#    macro avg       0.29      0.30      0.30       100
# weighted avg       0.30      0.30      0.30       100
#
#
# Confusion Matrix:
#  [[12 11 13]
#  [ 7 13 11]
#  [12 16  5]]
# ['model/label_encoder.pkl']

# %%
print(df.head())      # show first 5 rows
print(df.columns)     # show all column names
# Out:
#        alpha       beta     gamma     theta  emotion
# 0  11.993428  17.852355  6.399355  9.556722      Sad
# 1  10.723471  19.818833  5.924634  6.897629  Relaxed
# 2  12.295377  13.202865  5.059630  6.363602      Sad
# 3  14.046060  17.125938  4.353063  7.993251  Relaxed
# 4  10.531693  14.698715  5.698223  7.659631  Relaxed
# Index(['alpha', 'beta', 'gamma', 'theta', 'emotion'], dtype='object')

# %%
X = df.drop("emotion", axis=1)
y = df["emotion"]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Pick two features to visualize (replace with your actual column names)
feature_x = "alpha"
feature_y = "beta"

plt.figure(figsize=(8,6))
sns.scatterplot(x=df[feature_x], y=df[feature_y], hue=df["emotion"], palette="Set2", s=70)

plt.title(f"Scatter Plot of {feature_x} vs {feature_y}")
plt.xlabel(feature_x)
plt.ylabel(feature_y)
plt.legend(title="Emotion")
plt.show()

# %%
sns.pairplot(df, hue="emotion", diag_kind="kde", palette="Set2")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset
df = pd.read_csv("eeg_signals.csv")   # make sure your dataset has 'alpha','beta','emotion'

# Scatter plot
plt.figure(figsize=(8,6))
sns.scatterplot(x=df["alpha"], y=df["beta"], hue=df["emotion"], palette="Set2", s=70)

plt.title("EEG Scatter Plot (Alpha vs Beta)")
plt.xlabel("Alpha")
plt.ylabel("Beta")
plt.legend(title="Emotion")
plt.show()

# %%
import joblib

# Save model
joblib.dump(rf, "model/brainwave_model.pkl")

# Save scaler
joblib.dump(scaler, "model/scaler.pkl")

# Save label encoder
joblib.dump(le, "model/label_encoder.pkl")

# -----------------------
# Load model later
model = joblib.load("model/brainwave_model.pkl")
scaler = joblib.load("model/scaler.pkl")
le = joblib.load("model/label_encoder.pkl")

# %%
import pickle

# Save model
with open("model/brainwave_model.pkl", "wb") as f:
    pickle.dump(rf, f)

# Load model
with open("model/brainwave_model.pkl", "rb") as f:
    model = pickle.load(f)
